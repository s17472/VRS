# %%
import glob
import cv2
import os
import multiprocessing
import sys
import time

# %%
videosToExtract = glob.glob("C:/Users/Kuba/inz/dataset/train/Fight/*.avi");
outputDir = "C:/Users/Kuba/inz/dataset/train/Fight/extracted";

def cv_imread(file_path):
    cv_img = cv2.imdecode(np.fromfile(file_path, dtype=np.uint8), -1)
    return cv_img

# %%
len(videosToExtract);

# %%
def video_to_frames(input_loc, output_loc):
    """Function to extract frames from input video file
    and save them as separate frames in an output directory.
    Args:
        input_loc: Input video file.
        output_loc: Output directory to save the frames.
    Returns:
        None
    """
    try:
        os.mkdir(output_loc)
    except OSError:
        pass
    # Log the time
    time_start = time.time()
    # Start capturing the feed
    cap = cv2.VideoCapture(input_loc)
    # Find the number of frames
    video_length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) - 1
    print ("Number of frames: ", video_length)
    count = 0
    print ("Converting video..\n")
    # Start converting the video
    while cap.isOpened():
        # Extract the frame
        ret, frame = cap.read()
        # Write the results back to output location.
        cv2.imwrite(output_loc + "/%#05d.jpg" % (count+1), frame)
        count = count + 1
        # If there are no more frames left
        if (count > (video_length-1)):
            # Log the time again
            time_end = time.time()
            # Release the feed
            cap.release()
            # Print stats
            print ("Done extracting frames.\n%d frames extracted" % count)
            print ("It took %d seconds forconversion." % (time_end-time_start))
            break

# %%
for idx, video in enumerate(videosToExtract):
    print( f"{outputDir}/{idx}")
    video_to_frames(video, f"{outputDir}/{idx}")
# Out:
# C:/Users/Kuba/inz/dataset/train/Fight/extracted/0
# Number of frames:  149
# Converting video..
#
# Done extracting frames.
# 149 frames extracted
# It took 2 seconds forconversion.
# C:/Users/Kuba/inz/dataset/train/Fight/extracted/1
# Number of frames:  149
# Converting video..
#
# Done extracting frames.
# 149 frames extracted
# It took 3 seconds forconversion.
# C:/Users/Kuba/inz/dataset/train/Fight/extracted/2
# Number of frames:  149
# Converting video..
#
# Done extracting frames.
# 149 frames extracted
# It took 0 seconds forconversion.
# C:/Users/Kuba/inz/dataset/train/Fight/extracted/3
# Number of frames:  149
# Converting video..
#
# Done extracting frames.
# 149 frames extracted
# It took 0 seconds forconversion.
# C:/Users/Kuba/inz/dataset/train/Fight/extracted/4
# Number of frames:  149
# Converting video..
#
# Done extracting frames.
# 149 frames extracted
# It took 0 seconds forconversion.
# C:/Users/Kuba/inz/dataset/train/Fight/extracted/5
# Number of frames:  149
# ...
